# %%
import sys, os
sys.path.insert(0, os.path.abspath('../mie_nn'))
import Data

# %%
Data.generate_particles()
Data.load_and_prepare_training_data()
# Out:
# Generating 1000 particles with derivatives
#   particle 0/1000  (0.4s elapsed)
#   particle 25/1000  (11.0s elapsed)
#   particle 50/1000  (21.9s elapsed)
#   particle 75/1000  (33.8s elapsed)
#   particle 100/1000  (45.6s elapsed)
#   particle 125/1000  (56.8s elapsed)
#   particle 150/1000  (68.3s elapsed)
#   particle 175/1000  (79.4s elapsed)
#   particle 200/1000  (90.1s elapsed)
#   particle 225/1000  (100.9s elapsed)
#   particle 250/1000  (112.3s elapsed)
#   particle 275/1000  (123.3s elapsed)
#   particle 300/1000  (134.4s elapsed)
#   particle 325/1000  (145.0s elapsed)
#   particle 350/1000  (155.6s elapsed)
#   particle 375/1000  (166.1s elapsed)
#   particle 400/1000  (176.9s elapsed)
#   particle 425/1000  (187.8s elapsed)
#   particle 450/1000  (198.5s elapsed)
#   particle 475/1000  (209.1s elapsed)
#   particle 500/1000  (219.7s elapsed)
#   particle 525/1000  (231.0s elapsed)
#   particle 550/1000  (242.3s elapsed)
#   particle 575/1000  (253.6s elapsed)
#   particle 600/1000  (264.5s elapsed)
#   particle 625/1000  (275.2s elapsed)
#   particle 650/1000  (286.0s elapsed)
#   particle 675/1000  (296.9s elapsed)
#   particle 700/1000  (308.2s elapsed)
#   particle 725/1000  (319.6s elapsed)
#   particle 750/1000  (332.0s elapsed)
#   particle 775/1000  (344.3s elapsed)
#   particle 800/1000  (361.7s elapsed)
#   particle 825/1000  (373.9s elapsed)
#   particle 850/1000  (383.7s elapsed)
#   particle 875/1000  (393.3s elapsed)
#   particle 900/1000  (403.0s elapsed)
#   particle 925/1000  (412.5s elapsed)
#   particle 950/1000  (423.0s elapsed)
#   particle 975/1000  (432.9s elapsed)
#
# Done! Total time: 442.5s (0.44s per particle)
#
# Saved data
# Loaded 181000 training samples

# %%
Data.load_and_prepare_training_data()
# Out:
# Loaded 181000 training samples
